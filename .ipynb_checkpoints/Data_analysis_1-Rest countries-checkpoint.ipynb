# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt
import plotly           #(version 4.5.0)
import plotly.express as px
import plotly.io as pio

# %%
data=pd.read_csv("data_cleaned.csv")

# %%
data.head()
# Out:
#                      TransactionTime                      ItemDescription  \
# 523053  Mon Feb 12 04:26:00 IST 2018    GLASS STAR FROSTED T-LIGHT HOLDER
# 272948  Mon Feb 12 04:26:00 IST 2018                  WHITE METAL LANTERN
# 330926  Mon Feb 12 04:26:00 IST 2018       RED WOOLLY HOTTIE WHITE HEART.
# 395968  Mon Feb 12 04:26:00 IST 2018  KNITTED UNION FLAG HOT WATER BOTTLE
# 53508   Mon Feb 12 04:26:00 IST 2018         SET 7 BABUSHKA NESTING BOXES
#
#                Country  UserId  TransactionId  ItemCode  \
# 523053  United Kingdom  374850        5900015    456330
# 272948  United Kingdom  374850        5900015   1492113
# 330926  United Kingdom  374850        5900015   1764609
# 395968  United Kingdom  374850        5900015   1764609
# 53508   United Kingdom  374850        5900015    477792
#
#         NumberOfItemsPurchased  CostPerItem
# 523053                      18         5.87
# 272948                      18         4.68
# 330926                      18         4.68
# 395968                      18         4.68
# 53508                        6        10.56

# %%
import sweetviz
my_clean_report = sweetviz.analyze([data, "Data"])
# Out:
# :FEATURES DONE:                    |                     | [  0%]   00:06  -> (00:00 left)
# :PAIRWISE DONE:                    |█████████████████████| [100%]   00:02  -> (00:00 left)
# Creating Associations graph... DONE!

# %%
my_clean_report.show_html('Clean_report.html')

# %%
from pandas_profiling import ProfileReport

p = ProfileReport(data, title='Pandas Profiling Report', explorative=True)

# %%
p.to_widgets()
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=22.0, style=ProgressStyle(descrip…
# HBox(children=(FloatProgress(value=0.0, description='Generate report structure', max=1.0, style=ProgressStyle(…
# HBox(children=(FloatProgress(value=0.0, description='Render widgets', max=1.0, style=ProgressStyle(description…
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
p.to_file("output_clean.html")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Render HTML', max=1.0, style=ProgressStyle(description_wi…
# HBox(children=(FloatProgress(value=0.0, description='Export report to file', max=1.0, style=ProgressStyle(desc…

# %%
data.sort_values(by=['TransactionId'], inplace=True)

# %%
data.head()
# Out:
#                      TransactionTime                      ItemDescription  \
# 523053  Mon Feb 12 04:26:00 IST 2018    GLASS STAR FROSTED T-LIGHT HOLDER
# 272948  Mon Feb 12 04:26:00 IST 2018                  WHITE METAL LANTERN
# 330926  Mon Feb 12 04:26:00 IST 2018       RED WOOLLY HOTTIE WHITE HEART.
# 395968  Mon Feb 12 04:26:00 IST 2018  KNITTED UNION FLAG HOT WATER BOTTLE
# 53508   Mon Feb 12 04:26:00 IST 2018         SET 7 BABUSHKA NESTING BOXES
#
#                Country  UserId  TransactionId  ItemCode  \
# 523053  United Kingdom  374850        5900015    456330
# 272948  United Kingdom  374850        5900015   1492113
# 330926  United Kingdom  374850        5900015   1764609
# 395968  United Kingdom  374850        5900015   1764609
# 53508   United Kingdom  374850        5900015    477792
#
#         NumberOfItemsPurchased  CostPerItem
# 523053                      18         5.87
# 272948                      18         4.68
# 330926                      18         4.68
# 395968                      18         4.68
# 53508                        6        10.56

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 535118 entries, 523053 to 63756
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionTime         535118 non-null  object
#  1   ItemDescription         535118 non-null  object
#  2   Country                 535118 non-null  object
#  3   UserId                  535118 non-null  int64
#  4   TransactionId           535118 non-null  int64
#  5   ItemCode                535118 non-null  int64
#  6   NumberOfItemsPurchased  535118 non-null  int64
#  7   CostPerItem             535118 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 36.7+ MB

# %%
data.Country.value_counts()[:10].plot(kind='bar')

# %% [markdown]
# majority of customers are from the "United Kingdom"

# %%
uk_data=data[data.Country=='United Kingdom']

# %%
uk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488779 entries, 523053 to 367179
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionTime         488779 non-null  object
#  1   ItemDescription         488779 non-null  object
#  2   Country                 488779 non-null  object
#  3   UserId                  488779 non-null  int64
#  4   TransactionId           488779 non-null  int64
#  5   ItemCode                488779 non-null  int64
#  6   NumberOfItemsPurchased  488779 non-null  int64
#  7   CostPerItem             488779 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 33.6+ MB

# %%
uk_data.describe()
# Out:
#               UserId  TransactionId      ItemCode  NumberOfItemsPurchased  \
# count  488779.000000   4.887790e+05  4.887790e+05           488779.000000
# mean   238210.068569   6.159063e+06  6.654683e+05               26.169287
# std    147751.517874   1.484054e+05  4.577694e+05              686.212197
# min        -1.000000   5.900015e+06 -1.000000e+00          -242985.000000
# 25%        -1.000000   6.026350e+06  4.613070e+05                3.000000
# 50%    305067.000000   6.165544e+06  4.754820e+05                9.000000
# 75%    345240.000000   6.291241e+06  4.891740e+05               30.000000
# max    384027.000000   6.397446e+06  1.894494e+06           242985.000000
#
#         CostPerItem
# count  4.887790e+05
# mean   9.780696e+00
# std    2.430202e+03
# min   -1.526564e+04
# 25%    1.730000e+00
# 50%    2.900000e+00
# 75%    5.700000e+00
# max    1.696285e+06

# %%
uk_data = uk_data[(uk_data['NumberOfItemsPurchased']>0)]
uk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 480485 entries, 523053 to 367179
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionTime         480485 non-null  object
#  1   ItemDescription         480485 non-null  object
#  2   Country                 480485 non-null  object
#  3   UserId                  480485 non-null  int64
#  4   TransactionId           480485 non-null  int64
#  5   ItemCode                480485 non-null  int64
#  6   NumberOfItemsPurchased  480485 non-null  int64
#  7   CostPerItem             480485 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 33.0+ MB

# %%
uk_data = uk_data[(uk_data['UserId']>0)]
uk_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 349195 entries, 523053 to 367179
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TransactionTime         349195 non-null  object
#  1   ItemDescription         349195 non-null  object
#  2   Country                 349195 non-null  object
#  3   UserId                  349195 non-null  int64
#  4   TransactionId           349195 non-null  int64
#  5   ItemCode                349195 non-null  int64
#  6   NumberOfItemsPurchased  349195 non-null  int64
#  7   CostPerItem             349195 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 24.0+ MB

# %%
uk_data=uk_data[['UserId','TransactionTime','TransactionId','NumberOfItemsPurchased','CostPerItem']]

# %%
uk_data['TotalPrice'] = uk_data['NumberOfItemsPurchased'] * uk_data['CostPerItem']

# %%
uk_data.head()
# Out:
#         UserId               TransactionTime  TransactionId  \
# 523053  374850  Mon Feb 12 04:26:00 IST 2018        5900015
# 272948  374850  Mon Feb 12 04:26:00 IST 2018        5900015
# 330926  374850  Mon Feb 12 04:26:00 IST 2018        5900015
# 395968  374850  Mon Feb 12 04:26:00 IST 2018        5900015
# 53508   374850  Mon Feb 12 04:26:00 IST 2018        5900015
#
#         NumberOfItemsPurchased  CostPerItem  TotalPrice
# 523053                      18         5.87      105.66
# 272948                      18         4.68       84.24
# 330926                      18         4.68       84.24
# 395968                      18         4.68       84.24
# 53508                        6        10.56       63.36

# %%
uk_data.tail()
# Out:
#         UserId               TransactionTime  TransactionId  \
# 490480  331884  Wed Feb 20 08:31:00 IST 2019        6397435
# 148437  275373  Wed Feb 20 08:49:00 IST 2019        6397446
# 491661  275373  Wed Feb 20 08:49:00 IST 2019        6397446
# 370366  275373  Wed Feb 20 08:49:00 IST 2019        6397446
# 367179  275373  Wed Feb 20 08:49:00 IST 2019        6397446
#
#         NumberOfItemsPurchased  CostPerItem  TotalPrice
# 490480                      12         5.87       70.44
# 148437                      24         4.08       97.92
# 491661                      30         9.78      293.40
# 370366                      72         1.73      124.56
# 367179                      72        12.36      889.92

# %%
PRESENT = dt.datetime(2019,2,21)

# %%
uk_data['TransactionTime'] = pd.to_datetime(uk_data['TransactionTime'])

# %%
uk_data.head()
# Out:
#         UserId           TransactionTime  TransactionId  \
# 523053  374850 2018-02-12 04:26:00+05:30        5900015
# 272948  374850 2018-02-12 04:26:00+05:30        5900015
# 330926  374850 2018-02-12 04:26:00+05:30        5900015
# 395968  374850 2018-02-12 04:26:00+05:30        5900015
# 53508   374850 2018-02-12 04:26:00+05:30        5900015
#
#         NumberOfItemsPurchased  CostPerItem  TotalPrice
# 523053                      18         5.87      105.66
# 272948                      18         4.68       84.24
# 330926                      18         4.68       84.24
# 395968                      18         4.68       84.24
# 53508                        6        10.56       63.36

# %%
uk_data.tail()
# Out:
#         UserId           TransactionTime  TransactionId  \
# 490480  331884 2019-02-20 08:31:00+05:30        6397435
# 148437  275373 2019-02-20 08:49:00+05:30        6397446
# 491661  275373 2019-02-20 08:49:00+05:30        6397446
# 370366  275373 2019-02-20 08:49:00+05:30        6397446
# 367179  275373 2019-02-20 08:49:00+05:30        6397446
#
#         NumberOfItemsPurchased  CostPerItem  TotalPrice
# 490480                      12         5.87       70.44
# 148437                      24         4.08       97.92
# 491661                      30         9.78      293.40
# 370366                      72         1.73      124.56
# 367179                      72        12.36      889.92

# %%
PRESENT = dt.datetime(2019,2,21)

# %%
PRESENT
# Out:
# datetime.datetime(2019, 2, 21, 0, 0)

# %%
ts = pd.Timestamp('2019-02-21 00:00:00+05:30')
ts
# Out:
# Timestamp('2019-02-21 00:00:00+0530', tz='pytz.FixedOffset(330)')

# %%
uk_data['TransactionTime'][:-1]
# Out:
# 523053   2018-02-12 04:26:00+05:30
# 272948   2018-02-12 04:26:00+05:30
# 330926   2018-02-12 04:26:00+05:30
# 395968   2018-02-12 04:26:00+05:30
# 53508    2018-02-12 04:26:00+05:30
#                     ...
# 49468    2019-02-20 08:31:00+05:30
# 490480   2019-02-20 08:31:00+05:30
# 148437   2019-02-20 08:49:00+05:30
# 491661   2019-02-20 08:49:00+05:30
# 370366   2019-02-20 08:49:00+05:30
# Name: TransactionTime, Length: 349194, dtype: datetime64[ns, pytz.FixedOffset(330)]

# %%
uk_data.describe()
# Out:
#               UserId  TransactionId  NumberOfItemsPurchased   CostPerItem  \
# count  349195.000000   3.491950e+05           349195.000000  3.491950e+05
# mean   326514.777288   6.167109e+06               36.545188  8.964877e+00
# std     33482.353704   1.446319e+05              575.418675  2.870649e+03
# min    259266.000000   5.900015e+06                3.000000  0.000000e+00
# 25%    298011.000000   6.041684e+06                6.000000  1.730000e+00
# 50%    325878.000000   6.180801e+06               12.000000  2.700000e+00
# 75%    355551.000000   6.295091e+06               36.000000  5.180000e+00
# max    384027.000000   6.397446e+06           242985.000000  1.696285e+06
#
#          TotalPrice
# count  3.491950e+05
# mean   2.031398e+02
# std    6.890652e+04
# min    0.000000e+00
# 25%    1.740000e+01
# 50%    4.248000e+01
# 75%    7.398000e+01
# max    4.071085e+07

# %%
rfm= uk_data.groupby('UserId').agg({'TransactionTime': lambda date: (ts - date.max()).days,
                                        'TransactionId': lambda num: len(num),
                                        'TotalPrice': lambda price: price.sum()})

# %%
dd= uk_data.groupby('UserId')

# %%
dd.head()
# Out:
#         UserId           TransactionTime  TransactionId  \
# 523053  374850 2018-02-12 04:26:00+05:30        5900015
# 272948  374850 2018-02-12 04:26:00+05:30        5900015
# 330926  374850 2018-02-12 04:26:00+05:30        5900015
# 395968  374850 2018-02-12 04:26:00+05:30        5900015
# 53508   374850 2018-02-12 04:26:00+05:30        5900015
# ...        ...                       ...            ...
# 481756  305949 2019-02-19 10:58:00+05:30        6395576
# 197622  305949 2019-02-19 10:58:00+05:30        6395576
# 271886  305949 2019-02-19 10:58:00+05:30        6395576
# 359193  305949 2019-02-19 10:58:00+05:30        6395576
# 386692  345366 2019-02-20 05:15:00+05:30        6396313
#
#         NumberOfItemsPurchased  CostPerItem  TotalPrice
# 523053                      18         5.87      105.66
# 272948                      18         4.68       84.24
# 330926                      18         4.68       84.24
# 395968                      18         4.68       84.24
# 53508                        6        10.56       63.36
# ...                        ...          ...         ...
# 481756                       3        13.74       41.22
# 197622                       6         1.73       10.38
# 271886                       3         2.70        8.10
# 359193                     144         3.52      506.88
# 386692                  242985         2.88   699796.80
#
# [19024 rows x 6 columns]

# %%
rfm.head()
# Out:
#         TransactionTime  TransactionId  TotalPrice
# UserId
# 259266              325              1   320608.80
# 267687                2            103    17392.89
# 267708            -3285           4413   137149.41
# 267729                3            199    16957.44
# 269220                3             59     3910.62

# %%
# Change the name of columns
rfm.columns=['recency','frequency','monetary']

# %%
rfm['recency'] = rfm['recency'].astype(int)

# %%
rfm = rfm[(rfm['recency']>0)]
rfm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3834 entries, 259266 to 384027
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   recency    3834 non-null   int64
#  1   frequency  3834 non-null   int64
#  2   monetary   3834 non-null   float64
# dtypes: float64(1), int64(2)
# memory usage: 119.8 KB

# %%
rfm.head()
# Out:
#         recency  frequency   monetary
# UserId
# 259266      325          1  320608.80
# 267687        2        103   17392.89
# 267729        3        199   16957.44
# 269220        3         59    3910.62
# 269241      214          6     384.78

# %%
rfm['r_quartile'] = pd.qcut(rfm['recency'], 4, ['1','2','3','4'])
rfm['f_quartile'] = pd.qcut(rfm['frequency'], 4, ['4','3','2','1'])
rfm['m_quartile'] = pd.qcut(rfm['monetary'], 4, ['4','3','2','1'])

# %%
rfm.head()
# Out:
#         recency  frequency   monetary r_quartile f_quartile m_quartile
# UserId
# 259266      325          1  320608.80          4          4          1
# 267687        2        103   17392.89          1          1          1
# 267729        3        199   16957.44          1          1          1
# 269220        3         59    3910.62          1          2          2
# 269241      214          6     384.78          4          4          4

# %%
rfm['RFM_Score'] = rfm.r_quartile.astype(str)+ rfm.f_quartile.astype(str) + rfm.m_quartile.astype(str)
rfm.head()
# Out:
#         recency  frequency   monetary r_quartile f_quartile m_quartile  \
# UserId
# 259266      325          1  320608.80          4          4          1
# 267687        2        103   17392.89          1          1          1
# 267729        3        199   16957.44          1          1          1
# 269220        3         59    3910.62          1          2          2
# 269241      214          6     384.78          4          4          4
#
#        RFM_Score
# UserId
# 259266       441
# 267687       111
# 267729       111
# 269220       122
# 269241       444

# %%
rfm[rfm['RFM_Score']=='111'].sort_values('monetary', ascending=False).head()
# Out:
#         recency  frequency   monetary r_quartile f_quartile m_quartile  \
# UserId
# 350364        4        277  276619.29          1          1          1
# 287574        3        568  270246.84          1          1          1
# 296016        4       5111  270024.99          1          1          1
# 274869        2       1814  243753.90          1          1          1
# 331149        7        130  233471.40          1          1          1
#
#        RFM_Score
# UserId
# 350364       111
# 287574       111
# 296016       111
# 274869       111
# 331149       111

# %%
rfm.head()
# Out:
#         recency  frequency   monetary r_quartile f_quartile m_quartile  \
# UserId
# 259266      325          1  320608.80          4          4          1
# 267687        2        103   17392.89          1          1          1
# 267729        3        199   16957.44          1          1          1
# 269220        3         59    3910.62          1          2          2
# 269241      214          6     384.78          4          4          4
#
#        RFM_Score
# UserId
# 259266       441
# 267687       111
# 267729       111
# 269220       122
# 269241       444

# %%
rfm_transposed = rfm.T
rfm_transposed.head()
# Out:
# UserId      259266   267687   267729   269220  269241   269262  269283  \
# recency        325        2        3        3     214       70      74
# frequency        1      103      199       59       6       46       5
# monetary    320609  17392.9  16957.4  3910.62  384.78  3936.06  7286.4
# r_quartile       4        1        1        1       4        3       3
# f_quartile       4        1        1        2       4        2       4
#
# UserId       269304   269346   269367  ... 383733  383754   383796 383817  \
# recency          59        2        5  ...      2      30       43     58
# frequency        25       91       25  ...      3      11       14      8
# monetary    1647.24  6122.97  1784.52  ...  844.8  730.38  1393.38  458.4
# r_quartile        3        1        1  ...      1       2        2      3
# f_quartile        3        2        3  ...      4       4        4      4
#
# UserId     383838  383880 383901 383922   383943   384027
# recency        73     277    180      7        3       42
# frequency       9      10      7     12      721       70
# monetary    721.2  748.65  334.8  739.2  8490.27  7629.12
# r_quartile      3       4      4      1        1        2
# f_quartile      4       4      4      4        1        2
#
# [5 rows x 3834 columns]

# %%
rfm_transposed.columns
# Out:
# Int64Index([259266, 267687, 267729, 269220, 269241, 269262, 269283, 269304,
#             269346, 269367,
#             ...
#             383733, 383754, 383796, 383817, 383838, 383880, 383901, 383922,
#             383943, 384027],
#            dtype='int64', name='UserId', length=3834)

# %%
rfm.columns
# Out:
# Index(['recency', 'frequency', 'monetary', 'r_quartile', 'f_quartile',
#        'm_quartile', 'RFM_Score'],
#       dtype='object')

# %%
fig = px.scatter(rfm, x="RFM_Score", y="frequency", color=rfm_transposed.columns)
fig.show()
# Out:
# <div>
#
#
#             <div id="e0bad929-2988-4393-9057-b178225fe41f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("e0bad929-2988-4393-9057-b178225fe41f")) {
#                     Plotly.newPlot(
#                         'e0bad929-2988-4393-9057-b178225fe41f',
#                         [{"hovertemplate": "RFM_Score=%{x}<br>frequency=%{y}<br>UserId=%{marker.color}<extra></extra>", "legendgroup": "", "marker": {"color": [259266, 267687, 267729, 269220, 269241, 269262, 269283, 269304, 269346, 269367, 269388, 269409, 269430, 269451, 269472, 269493, 269514, 269556, 269577, 269598, 269640, 269661, 269682, 269703, 269724, 269745, 269787, 269829, 269871, 269892, 269913, 269934, 269955, 269976, 269997, 270123, 270144, 270207, 270228, 270291, 270312, 270333, 270375, 270417, 270438, 270459, 270501, 270522, 270543, 270564, 270585, 270606, 270648, 270690, 270711, 270753, 270795, 270837, 270921, 270942, 270984, 271026, 271068, 271089, 271110, 271152, 271173, 271215, 271236, 271257, 271299, 271320, 271341, 271362, 271383, 271404, 271425, 271488, 271509, 271530, 271551, 271593, 271635, 271656, 271677, 271698, 271719, 271740, 271782, 271824, 271845, 271887, 271908, 271929, 271950, 271971, 271992, 272013, 272055, 272076, 272097, 272202, 272223, 272265, 272286, 272307, 272328, 272370, 272454, 272496, 272517, 272580, 272601, 272622, 272664, 272727, 272748, 272769, 272790, 272811, 272853, 272874, 272895, 272937, 272979, 273000, 273021, 273042, 273063, 273084, 273105, 273126, 273168, 273231, 273252, 273273, 273294, 273315, 273336, 273357, 273378, 273441, 273483, 273546, 273567, 273588, 273609, 273630, 273672, 273693, 273714, 273735, 273777, 273798, 273840, 273903, 273924, 273945, 273966, 273987, 274008, 274029, 274050, 274092, 274155, 274218, 274239, 274260, 274281, 274302, 274344, 274365, 274386, 274407, 274428, 274470, 274512, 274575, 274617, 274638, 274659, 274680, 274701, 274722, 274743, 274785, 274869, 274890, 274911, 274932, 274953, 274974, 274995, 275037, 275058, 275079, 275121, 275142, 275163, 275184, 275226, 275247, 275268, 275289, 275310, 275415, 275436, 275457, 275478, 275520, 275541, 275562, 275604, 275646, 275667, 275730, 275751, 275772, 275793, 275814, 275835, 275856, 275877, 275898, 275919, 275940, 275961, 275982, 276024, 276045, 276066, 276087, 276108, 276129, 276171, 276213, 276255, 276297, 276318, 276339, 276360, 276381, 276402, 276465, 276486, 276507, 276528, 276549, 276570, 276591, 276654, 276696, 276717, 276738, 276822, 276843, 276864, 276885, 276906, 276927, 276948, 276969, 277032, 277053, 277074, 277116, 277158, 277179, 277200, 277263, 277347, 277368, 277389, 277410, 277431, 277452, 277473, 277536, 277557, 277578, 277620, 277641, 277683, 277704, 277725, 277746, 277767, 277788, 277809, 277830, 277872, 277893, 277935, 277956, 277998, 278019, 278040, 278082, 278103, 278124, 278145, 278166, 278187, 278208, 278229, 278313, 278355, 278376, 278418, 278439, 278460, 278481, 278502, 278523, 278565, 278586, 278607, 278628, 278649, 278670, 278691, 278712, 278733, 278796, 278817, 278838, 278859, 278880, 278922, 278943, 278964, 278985, 279111, 279132, 279174, 279195, 279216, 279237, 279258, 279279, 279300, 279321, 279342, 279384, 279405, 279447, 279468, 279489, 279510, 279531, 279573, 279594, 279636, 279657, 279678, 279699, 279720, 279741, 279762, 279783, 279804, 279825, 279867, 279888, 279909, 279930, 279972, 280014, 280056, 280098, 280119, 280140, 280161, 280203, 280224, 280245, 280287, 280308, 280329, 280350, 280371, 280392, 280434, 280455, 280476, 280497, 280518, 280539, 280602, 280623, 280644, 280665, 280686, 280728, 280749, 280770, 280812, 280833, 280875, 280896, 280959, 281001, 281022, 281064, 281085, 281148, 281169, 281190, 281211, 281274, 281295, 281316, 281337, 281358, 281442, 281463, 281484, 281505, 281568, 281610, 281631, 281694, 281736, 281757, 281778, 281799, 281820, 281841, 281862, 281925, 281967, 281988, 282009, 282030, 282051, 282114, 282135, 282156, 282177, 282219, 282261, 282387, 282408, 282429, 282450, 282471, 282492, 282513, 282555, 282576, 282618, 282660, 282681, 282702, 282744, 282786, 282807, 282828, 282870, 282891, 282933, 282954, 282975, 282996, 283017, 283059, 283101, 283122, 283143, 283164, 283185, 283206, 283227, 283269, 283311, 283374, 283395, 283416, 283437, 283479,  ...
